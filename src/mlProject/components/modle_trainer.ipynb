# %%
import pandas as pd
import os  
import mlProject import logger
from sklearn.linear_model import ElasticNet
import joblib
from mlProject.entity.config_entity import ModelTrainerConfig
from mlProject.utils.common import read_yaml, create_directories
