# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Python AI ML DL\\ML Flow e-t-e\\E-to-E-ML-Project-using-ML-Flow\\research'

# %%
os.chdir("d:\\Python AI ML DL\\ML Flow e-t-e\\E-to-E-ML-Project-using-ML-Flow")

# %%
# %pwd
# Out:
# 'd:\\Python AI ML DL\\ML Flow e-t-e\\E-to-E-ML-Project-using-ML-Flow'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path
    transformed_data_path: Path

# %%
from src.mlProject.constants import *
from mlProject.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH
        ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
            transformed_data_path=config.transformed_data_path,
        )

        return data_transformation_config

# %%
import os
from mlProject import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
        from sklearn.model_selection import train_test_split
        train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(data_transformation_config)
    data_transformation.perform_train_test_split()
except Exception as e:
    logger.exception(e)
# Out:
# [2026-04-20 15:47:42,059: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-04-20 15:47:42,062: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-04-20 15:47:42,067: INFO: common: yaml file: schema.yaml loaded successfully]
# [2026-04-20 15:47:42,070: INFO: common: created directory at: artifacts]
# [2026-04-20 15:47:42,072: INFO: common: created directory at: artifacts/data_transformation]
# Loading data from: artifacts/data_ingestion/WineQT (1).csv
# Data shape: (1143, 13)
# Saving train data to: artifacts/data_transformation\train_data.csv
# Saving test data to: artifacts/data_transformation\test_data.csv
# [2026-04-20 15:47:42,097: INFO: 1294747481: Data transformation completed. Train and test data saved in artifacts/data_transformation]
# [2026-04-20 15:47:42,099: INFO: 1294747481: Train data shape: (914, 13)]
# [2026-04-20 15:47:42,101: INFO: 1294747481: Test data shape: (229, 13)]
# Train data shape: (914, 13)
# Test data shape: (229, 13)

# %%
# Test data loading
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    print(f"Config loaded: {data_transformation_config}")

    data = pd.read_csv(data_transformation_config.data_path)
    print(f"Data loaded successfully. Shape: {data.shape}")
    print(f"Data path: {data_transformation_config.data_path}")
    print(f"Root dir: {data_transformation_config.root_dir}")
except Exception as e:
    print(f"Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# [2026-04-20 15:46:44,281: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-04-20 15:46:44,285: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-04-20 15:46:44,292: INFO: common: yaml file: schema.yaml loaded successfully]
# [2026-04-20 15:46:44,294: INFO: common: created directory at: artifacts]
# [2026-04-20 15:46:44,296: INFO: common: created directory at: artifacts/data_transformation]
# Config loaded: DataTransformationConfig(root_dir='artifacts/data_transformation', data_path='artifacts/data_ingestion/WineQT (1).csv', transformed_data_path='artifacts/data_transformation/transformed_data.csv')
# Data loaded successfully. Shape: (1143, 13)
# Data path: artifacts/data_ingestion/WineQT (1).csv
# Root dir: artifacts/data_transformation
