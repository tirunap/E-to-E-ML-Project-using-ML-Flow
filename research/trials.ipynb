# %%
d = {"key":"value", "key1":"value2"}

# %%
d["key"]
# Out:
# 'value'

# %%
import sys
print(sys.executable)
# Out:
# d:\Python AI ML DL\ML Flow e-t-e\E-to-E-ML-Project-using-ML-Flow\.venv\Scripts\python.exe

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"value", "key1":"value2"})

# %%
d2.key
# Out:
# 'value'

# %%
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2,y=4)
# Out:
# 8

# %%
get_prodict(x=2,y="4")
# Out:
# '44'

# %%
from ensure import ensure_annotations
